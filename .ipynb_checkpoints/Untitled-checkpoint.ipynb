# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_palette(sns.color_palette("RdBu", n_colors=8, desat=1.))
sns.set_style("white")
sns.set_style({'grid.color': '0.95'})
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

# %%
bands = np.loadtxt("bands.csv", delimiter = ',')

# %%
NK = 512
NA = 2
fig = plt.figure(1, figsize = (10, 8))
ax = fig.add_subplot(1, 1, 1)
#ax.plot(np.linspace(-np.pi / NA, np.pi / NA, num=NK,\
#        endpoint=False), np.concatenate((bands[int(NK/2):],bands[:int(NK/2)])), linewidth = 0.8, color = 'darkblue')
ax.plot(np.linspace(-np.pi / NA, np.pi / NA, num=NK + 1,\
        endpoint=False), bands, linewidth = 0.8, color = 'darkblue')
ax.set_xlabel(r'$k$', fontsize = 12)
ax.set_ylabel(r'$\varepsilon_{k, \sigma} [eV]$', rotation = 0,\
fontsize = 12, labelpad = 30)
ax.set_xticks([-np.pi / NA, 0, np.pi / NA])
if NA == 1:
    ax.set_xticklabels([r'$-\pi$', r'$0$', r'$\pi$'])
else:
    ax.set_xticklabels([r'$-\pi / ' + str(NA) + '$', r'$0$', r'$\pi / ' + str(NA) + '$'])
